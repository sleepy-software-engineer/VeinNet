# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
rows = (len(spectrum_types) + 1) // 2  # Calculate the number of rows needed
fig, axes = plt.subplots(rows, 2, figsize=(20, 10 * rows))  # Increase the height of the figure

for ax, spectrum in zip(axes.flatten(), spectrum_types):
    pattern = f"{selected_person}_{selected_hand}_{spectrum}_*.jpg"
    selected_files = glob.glob(dataset + pattern)[:1]
    if selected_files:
        print(selected_files[0])
        img = cv2.imread(selected_files[0])
        ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        ax.set_title(spectrum, fontsize=40)  # Increase the font size of the title
    ax.axis('off')

# Hide any unused subplots
for ax in axes.flatten()[len(spectrum_types):]:
    ax.axis('off')

plt.tight_layout()  # Make the layout more compact
plt.show()
# Out:
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_460_01.jpg
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_630_05.jpg
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_700_05.jpg
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_850_06.jpg
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_940_01.jpg
# /home/lucian/University/MSc-Courses/BiometricSystems/data/008_l_WHT_05.jpg
